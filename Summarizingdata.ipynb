# %% [markdown]
# <a href="https://colab.research.google.com/github/BaRobles/Ada-Lovelace/blob/main/Summarizingdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20200101', periods=6)

df = pd.DataFrame(np.random.randn(6, 4), index=datas, columns=['Var_A', 'Var_B', 'Var_C', 'Var_D'])

# %%
df2 = pd.DataFrame({
    'A': 1,
    'B': pd.Timestamp('20130102'),
    'C': pd.Series(1, index=list(range(4)), dtype='float32'),
    'D': np.array([3] * 4, dtype='int32'),
    'E': pd.Categorical(['test', 'train', 'test', 'train']),
    'F': 'Python'
})

# %%
df
# Out:
#                Var_A     Var_B     Var_C     Var_D
# 2020-01-01  0.818068  1.349299 -0.004507 -0.427184
# 2020-01-02  1.609133 -0.793630  1.087899 -0.566425
# 2020-01-03  1.121075 -0.967675 -0.340811 -0.684985
# 2020-01-04 -0.820667 -0.191207 -0.803373  0.956486
# 2020-01-05 -0.925620  0.429432  0.092270 -2.155111
# 2020-01-06  0.546338 -0.760748 -1.232015  0.535312

# %%
df.dtypes
# Out:
# Var_A    float64
# Var_B    float64
# Var_C    float64
# Var_D    float64
# dtype: object

# %%
df2
# Out:
#    A          B    C  D      E       F
# 0  1 2013-01-02  1.0  3   test  Python
# 1  1 2013-01-02  1.0  3  train  Python
# 2  1 2013-01-02  1.0  3   test  Python
# 3  1 2013-01-02  1.0  3  train  Python

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.describe()
# Out:
#          A    C    D
# count  4.0  4.0  4.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
df1 = df.reindex(index=datas[0:4], columns=list(df.columns) + ['Var_E'])
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.818068  1.349299 -0.004507 -0.427184    NaN
# 2020-01-02  1.609133 -0.793630  1.087899 -0.566425    NaN
# 2020-01-03  1.121075 -0.967675 -0.340811 -0.684985    NaN
# 2020-01-04 -0.820667 -0.191207 -0.803373  0.956486    NaN

# %%
# adding values to Var_E
df1.loc[datas[0]:datas[1], 'Var_E'] = 1
df1
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.818068  1.349299 -0.004507 -0.427184    1.0
# 2020-01-02  1.609133 -0.793630  1.087899 -0.566425    1.0
# 2020-01-03  1.121075 -0.967675 -0.340811 -0.684985    NaN
# 2020-01-04 -0.820667 -0.191207 -0.803373  0.956486    NaN

# %%
df1.describe()
# Out:
#           Var_A     Var_B     Var_C     Var_D  Var_E
# count  4.000000  4.000000  4.000000  4.000000    2.0
# mean   0.681902 -0.150803 -0.015198 -0.180527    1.0
# std    1.053389  1.053952  0.805022  0.765296    0.0
# min   -0.820667 -0.967675 -0.803373 -0.684985    1.0
# 25%    0.408384 -0.837141 -0.456451 -0.596065    1.0
# 50%    0.969571 -0.492419 -0.172659 -0.496804    1.0
# 75%    1.243089  0.193919  0.268594 -0.081266    1.0
# max    1.609133  1.349299  1.087899  0.956486    1.0

# %%
# Out:
#                Var_A     Var_B     Var_C     Var_D  Var_E
# 2020-01-01  0.818068  1.349299 -0.004507 -0.427184    1.0
# 2020-01-02  1.609133 -0.793630  1.087899 -0.566425    1.0
# 2020-01-03  1.121075 -0.967675 -0.340811 -0.684985    NaN
# 2020-01-04 -0.820667 -0.191207 -0.803373  0.956486    NaN
